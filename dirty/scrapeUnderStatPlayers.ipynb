# %%
import asyncio
import json

import aiohttp

from understat import Understat

# %%
async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        players = await understat.get_league_players(
            "epl",
            2019
        )
        print(json.dumps(players))

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-dac37d184342> in <module>
#       9
#      10 loop = asyncio.get_event_loop()
# ---> 11 loop.run_until_complete(main())
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     568         future.add_done_callback(_run_until_complete_cb)
#     569         try:
# --> 570             self.run_forever()
#     571         except:
#     572             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     523         self._check_closed()
#     524         if self.is_running():
# --> 525             raise RuntimeError('This event loop is already running')
#     526         if events._get_running_loop() is not None:
#     527             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# [{"id": "755", "player_name": "Jamie Vardy", "games": "27", "time": "2314", "goals": "19", "xG": "14.41597581654787", "assists": "4", "xA": "3.4716843869537115", "shots": "61", "key_passes": "18", "yellow_cards": "2", "red_cards": "0", "position": "F S", "team_title": "Leicester", "npg": "15", "npxG": "10.610131613910198", "xGChain": "13.923162683844566", "xGBuildup": "1.4771184585988522"}, {"id": "318", "player_name": "Pierre-Emerick Aubameyang", "games": "28", "time": "2489", "goals": "17", "xG": "12.841656951233745", "assists": "1", "xA": "3.3758759424090385", "shots": "74", "key_passes": "21", "yellow_cards": "3", "red_cards": "1", "position": "F M", "team_title": "Arsenal", "npg": "16", "npxG": "12.080524979159236", "xGChain": "16.06822992116213", "xGBuildup": "4.440667852759361"}, {"id": "619", "player_name": "Sergio Ag\u00fcero", "games": "23", "time": "1414", "goals": "16", "xG": "15.476871341466904", "assists": "3", "xA": "2.9202088303864002", "shots": "75", "key_passes": "19", "yellow_cards": "1", "red_cards": "0", "position": "F S", "team_title": "Manchester City", "npg": "14", "npxG": "13.19340169429779", "xGChain": "16.79762502014637", "xGBuildup": "2.644766173325479"}, {"id": "986", "player_name": "Danny Ings", "games": "30", "time": "2116", "goals": "16", "xG": "11.614945640787482", "assists": "2", "xA": "2.200341354124248", "shots": "72", "key_passes": "25", "yellow_cards": "3", "red_cards": "0", "position": "F M S", "team_title": "Southampton", "npg": "16", "npxG": "11.614945640787482", "xGChain": "13.589987881481647", "xGBuildup": "2.767123803496361"}, {"id": "1250", "player_name": "Mohamed Salah", "games": "26", "time": "2265", "goals": "16", "xG": "15.535896979272366", "assists": "6", "xA": "7.2400669902563095", "shots": "98", "key_passes": "47", "yellow_cards": "1", "red_cards": "0", "position": "F", "team_title": "Liverpool", "npg": "13", "npxG": "13.252390407025814", "xGChain": "23.791065126657486", "xGBuildup": "6.689902920275927"}, {"id": "556", "player_name": "Marcus Rashford", "games": "23", "time": "1980", "goals": "14", "xG": "15.494197219610214", "assists": "4", "xA": "3.2541757728904486", "shots": "76", "key_passes": "25", "yellow_cards": "2", "red_cards": "0", "position": "F M", "team_title": "Manchester United", "npg": "9", "npxG": "10.166052158921957", "xGChain": "13.758684678003192", "xGBuildup": "3.3678588289767504"}, {"id": "838", "player_name": "Sadio Man\u00e9", "games": "27", "time": "2180", "goals": "14", "xG": "12.425493717193604", "assists": "7", "xA": "5.050685964524746", "shots": "60", "key_passes": "43", "yellow_cards": "2", "red_cards": "0", "position": "F M S", "team_title": "Liverpool", "npg": "14", "npxG": "12.425493717193604", "xGChain": "19.919755160808563", "xGBuildup": "5.02796745300293"}, {"id": "4105", "player_name": "Ra\u00fal Jim\u00e9nez", "games": "30", "time": "2563", "goals": "14", "xG": "14.7457867115736", "assists": "6", "xA": "6.719611827284098", "shots": "102", "key_passes": "44", "yellow_cards": "3", "red_cards": "0", "position": "F S", "team_title": "Wolverhampton Wanderers", "npg": "11", "npxG": "12.462280169129372", "xGChain": "20.471002504229546", "xGBuildup": "4.716690460219979"}, {"id": "702", "player_name": "Tammy Abraham", "games": "26", "time": "1983", "goals": "13", "xG": "13.512620009481907", "assists": "3", "xA": "2.852206479758024", "shots": "74", "key_passes": "20", "yellow_cards": "2", "red_cards": "0", "position": "F S", "team_title": "Chelsea", "npg": "13", "npxG": "13.512620009481907", "xGChain": "15.421988274902105", "xGBuildup": "0.994125047698617"}, {"id": "5555", "player_name": "Dominic Calvert-Lewin", "games": "28", "time": "2009", "goals": "13", "xG": "14.303945859894156", "assists": "1", "xA": "1.3362248316407204", "shots": "67", "key_passes": "15", "yellow_cards": "7", "red_cards": "0", "position": "F S", "team_title": "Everton", "npg": "13", "npxG": "14.303945859894156", "xGChain": "15.609888322651386", "xGBuildup": "3.410177739337086 ...

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-06cc9e5d4867> in <module>
#      10
#      11 loop = asyncio.get_event_loop()
# ---> 12 loop.run_until_complete(main())
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     568         future.add_done_callback(_run_until_complete_cb)
#     569         try:
# --> 570             self.run_forever()
#     571         except:
#     572             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     523         self._check_closed()
#     524         if self.is_running():
# --> 525             raise RuntimeError('This event loop is already running')
#     526         if events._get_running_loop() is not None:
#     527             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
pip install understat
# Out:
# Collecting understat
#   Using cached understat-0.1.2-py3-none-any.whl (6.6 kB)
# Collecting bs4
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# Collecting pytest-mock
#   Using cached pytest_mock-3.1.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytest in c:\users\mimbu\anaconda3\lib\site-packages (from understat) (5.3.4)
# Collecting pytest-cov
#   Using cached pytest_cov-2.8.1-py2.py3-none-any.whl (18 kB)
# Collecting pytest-aiohttp
#   Using cached pytest_aiohttp-0.3.0-py3-none-any.whl (3.9 kB)
# Collecting codecov
#   Using cached codecov-2.0.22-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: aiohttp in c:\users\mimbu\anaconda3\lib\site-packages (from understat) (3.6.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\mimbu\anaconda3\lib\site-packages (from bs4->understat) (4.8.2)
# Requirement already satisfied: py>=1.5.0 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (1.8.1)
# Requirement already satisfied: packaging in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (8.0.2)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (0.1.7)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (1.4.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mimbu\anaconda3\lib\site-packages (from pytest->understat) (0.4.3)
# Collecting coverage>=4.4
#   Downloading coverage-5.1-cp37-cp37m-win_amd64.whl (205 kB)
# Requirement already satisfied: requests>=2.7.9 in c:\users\mimbu\anaconda3\lib\site-packages (from codecov->understat) (2.22.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mimbu\anaconda3\lib\site-packages (from aiohttp->understat) (1.4.2)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\users\mimbu\anaconda3\lib\site-packages (from aiohttp->understat) (3.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\users\mimbu\anaconda3\lib\site-packages (from aiohttp->understat) (3.0.1)
# Requirement already satisfied: multidict<5.0,>=4.5 in c:\users\mimbu\anaconda3\lib\site-packages (from aiohttp->understat) (4.7.3)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\mimbu\anaconda3\lib\site-packages (from beautifulsoup4->bs4->understat) (1.9.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mimbu\anaconda3\lib\site-packages (from packaging->pytest->understat) (2.4.6)
# Requirement already satisfied: six in c:\users\mimbu\anaconda3\lib\site-packages (from packaging->pytest->understat) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mimbu\anaconda3\lib\site-packages (from importlib-metadata>=0.12->pytest->understat) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mimbu\anaconda3\lib\site-packages (from requests>=2.7.9->codecov->understat) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\mimbu\anaconda3\lib\site-packages (from requests>=2.7.9->codecov->understat) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mimbu\anaconda3\lib\site-packages (from requests>=2.7.9->codecov->understat) (1.25.8)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1278 sha256=9d399f56def00e82307df33a7637ab37bc2c65430bc0bba6168fe560ae0f52b3
#   Stored in directory: c:\users\mimbu\appdata\local\pip\cache\wheels\0a\9e\ba\20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# Installing collected packages: bs4, pytest-mock, coverage, pytest-cov, pytest-aiohttp, codecov, understat
# Successfully installed bs4-0.0.1 codecov-2.0.22 coverage-5.1 pytest-aiohttp-0.3.0 pytest-cov-2.8.1 pytest-mock-3.1.0 understat-0.1.2
# Note: you may need to restart the kernel to use updated packages.
